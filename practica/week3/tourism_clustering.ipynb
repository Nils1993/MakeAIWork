# %%
import pandas as pd
import csv as csv

# %%
path_to_file = "C:/Users/nilsm/MakeAIWork/data/csv/bijdrage-van-het-toerisme-aan-de-totale-werkgelegenheid__contribution-of-tourism-to-total-employment.csv"

sp_data = pd.read_csv(path_to_file)

# %%
sp_data.shape
# Out:
# (28, 8)

# %%
sp_data.columns
# Out:
# Index(['VERSIONS', 'LEVEL_ID', 'TERRITORY_ID', 'NAME_HTML', 'YEAR', 'DATE',
#        'UNIT', 'VALUE'],
#       dtype='object')

# %%
sp_data.head()
# Out:
#      VERSIONS  LEVEL_ID TERRITORY_ID NAME_HTML  YEAR  DATE  UNIT  VALUE
# 0  2016, 2021         0           AT   Austria  2019  2019  PERC  18.55
# 1  2016, 2021         0           BE   Belgium  2019  2019  PERC   8.58
# 2  2016, 2021         0           BG  Bulgaria  2019  2019  PERC   5.97
# 3  2016, 2021         0           CY    Cyprus  2019  2019  PERC  18.21
# 4  2016, 2021         0           CZ   Czechia  2019  2019  PERC   9.68

# %%
sp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Columns: 518 entries, Unnamed: 0 to HSIC
# dtypes: float64(517), object(1)
# memory usage: 22.3+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x=sp_data['NAME_HTML'], y=sp_data['VALUE'])
# Out:
# <AxesSubplot: xlabel='NAME_HTML', ylabel='VALUE'>

# %%
import scipy.cluster.hierarchy as shc

sp_data.plot('NAME_HTML', 'VALUE', label='work by tourism', kind='bar')
# Out:
# <AxesSubplot: xlabel='NAME_HTML'>
